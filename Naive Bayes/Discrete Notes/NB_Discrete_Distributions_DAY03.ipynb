# %% [markdown]
# # Discrete Distribution
# ---

# %%
Binomial Distribution -  2 outcomes , Probablities Remain Same -  Toss
Multinomial Distribution - Multiple Outcomes  , Probablities Remain Same  -- Dice
Poisson Distribution   - Probablities of Occurances thats are very less - Typos

# %% [markdown]
# # Binomial Distribution / Multi-Nomial Distribution

# %% [markdown]
# ![Screenshot 2024-11-15 142937.png](data:image/png;base64,...)

# %% [markdown]
# Formula for the Binomial Distribution

# %% [markdown]
# ![Screenshot 2024-11-15 143105.png](data:image/png;base64,...)

# %% [markdown]
# Binomial Distribution tends to become like Normal / Guassian Distribution as the value fo n increases that is no of trials increase and probablities remain same

# %% [markdown]
# ![Screenshot 2024-11-15 145048.png](data:image/png;base64,...)

# %% [markdown]
# # Poisson Distribution

# %% [markdown]
# We use this when the probablity of event occuring is very small .

# %% [markdown]
# ![Screenshot 2024-11-15 145305.png](data:image/png;base64,...)

# %% [markdown]
# # Normal Approximation of Poisson Distribution

# %% [markdown]
# When the Poisson Distribution no increases , it tends to look like a binomial distribution which in turn if done a large no of times
# Will tend to look like A Normal Distribution

# %% [markdown]
# ![Screenshot 2024-11-15 145620.png](data:image/png;base64,...)![Screenshot 2024-11-15 145456.png](data:image/png;base64,...)

# %% [markdown]
# # Comparison between Binomial / Multinomial Distribution &  Poisson Distribution

# %% [markdown]
# ![Screenshot 2024-11-15 150439.png](data:image/png;base64,...)
